# %%
import matplotlib.pyplot as plt

# %%
import nltk
import pandas as pd
import string

# %%
messages1 = [line.rstrip() for line in open("data/presidential-campaign-trail/Trump.txt", encoding='utf-8')]
messages2 = [line.rstrip() for line in open("data/presidential-campaign-trail/Clinton.txt", encoding='utf-8')]
messages3 = [line.rstrip() for line in open("data/presidential-campaign-trail/Romney.txt", encoding='utf-8')]
messages4 = [line.rstrip() for line in open("data/presidential-campaign-trail/Obama.txt", encoding='utf-8')]

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# install Vader and make sure you download the lexicon as well
sid = SentimentIntensityAnalyzer()
# this step will return an error if you have not installed the lexicon

# %%
summary = {"positive":0,"neutral":0,"negative":0}
labels = ["Positive","Neutral", "Negative"]
colors = ["green", "yellow","red"]
explode = (0,0.1,0)
for x in messages1: 
    ss = sid.polarity_scores(x)
    if ss["compound"] == 0.0: 
        summary["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary["positive"] +=1
    else:
        summary["negative"] +=1
print(summary)
plt.title("Trump Speech")
trump = plt.pie(scores, labels=labels,explode = explode, colors = colors, autopct = "%#1.1f%%", shadow =True,startangle = 140)
plt.axis("equal")
plt.show(trump)
# Out:
# {'positive': 34, 'neutral': 56, 'negative': 5}
# <img src="data:image/png;base64,..." width="640">

# %%
summary = {"positive":0,"neutral":0,"negative":0}

labels = ["Positive","Neutral", "Negative"]
colors = ["green", "yellow","red"]
explode = (0,0.1,0)
for x in messages2: 
    ss = sid.polarity_scores(x)
    if ss["compound"] == 0.0: 
        summary["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary["positive"] +=1
    else:
        summary["negative"] +=1
print(summary)
plt.title("Clinton Speech")
clinton = plt.pie(scores, labels=labels,explode = explode, colors = colors, autopct = "%#1.1f%%", shadow =True,startangle = 140)
plt.axis("equal")
plt.show(clinton)
# Out:
# {'positive': 48, 'neutral': 25, 'negative': 25}

# %%
summary = {"positive":0,"neutral":0,"negative":0}

labels = ["Positive","Neutral", "Negative"]
colors = ["green", "yellow","red"]
explode = (0,0.1,0)
for x in messages3: 
    ss = sid.polarity_scores(x)
    if ss["compound"] == 0.0: 
        summary["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary["positive"] +=1
    else:
        summary["negative"] +=1
print(summary)
plt.title("Romney Speech")
Romney = plt.pie(scores, labels=labels,explode = explode, colors = colors, autopct = "%#1.1f%%", shadow =True,startangle = 140)
plt.axis("equal")
plt.show(Romney)
# Out:
# {'positive': 25, 'neutral': 1, 'negative': 5}

# %%
summary = {"positive":0,"neutral":0,"negative":0}

labels = ["Positive","Neutral", "Negative"]
colors = ["green", "yellow","red"]
explode = (0,0.1,0)
for x in messages4: 
    ss = sid.polarity_scores(x)
    if ss["compound"] == 0.0: 
        summary["neutral"] +=1
    elif ss["compound"] > 0.0:
        summary["positive"] +=1
    else:
        summary["negative"] +=1
print(summary)
plt.title("Obama Speech")
obama = plt.pie(scores, labels=labels,explode = explode, colors = colors, autopct = "%#1.1f%%", shadow =True,startangle = 140)
plt.axis("equal")
plt.show(obama)
# Out:
# {'positive': 119, 'neutral': 53, 'negative': 32}
