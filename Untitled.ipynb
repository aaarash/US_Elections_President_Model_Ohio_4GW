# %%
import requests
import json

# %%
url = "https://api.datausa.io/api/?sort=desc&force=acs.yg_income_distribution&show=geo&sumlevel=all&year=all&geo=01000US%2C04000US39"

# %%
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         [
#             2013,
#             "01000US",
#             9326850.0,
#             40023.0,
#             6246220.0,
#             40738.0,
#             5423050.0,
#             38313.0,
#             5644220.0,
#             28751.0,
#             6199800.0,
#             41979.0,
#             5842620.0,
#             33088.0,
#             6375880.0,
#             42979.0,
#             5905620.0,
#             35079.0,
#             6058650.0,
#             34859.0,
#             5484000.0,
#             39507.0,
#             5506750.0,
#             39177.0,
#             4849960.0,
#             33574.0,
#             9201120.0,
#             54177.0,
#             11619400.0,
#             48912.0,
#             13823800.0,
#             56657.0,
#             8783120.0,
#             42582.0,
#             116291000.0,
#             141632.0
#         ],
#         [
#             2014,
#             "01000US",
#             9609100.0,
# ...
