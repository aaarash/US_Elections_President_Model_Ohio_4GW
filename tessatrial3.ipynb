# %%
# Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
#Load medicare enrollment data csv (from DataUSA)

medicare_df = pd.read_csv("../Tessa_ohio/OhioCounties_MedicareData.csv")
medicare_df.head()
# Out:
#              geo_name geo_sumlevel        geo_id  total_reimbursements_b_2010  \
# 0  Baldwin County, AL       county  05000US01003                       9618.0
# 1  Barbour County, AL       county  05000US01005                       9761.0
# 2     Bibb County, AL       county  05000US01007                      11269.0
# 3   Blount County, AL       county  05000US01009                      10238.0
# 4  Bullock County, AL       county  05000US01011                       9567.0
#
#    total_reimbursements_b_2011  total_reimbursements_b_2012  \
# 0                       9569.0                       9501.0
# 1                      10718.0                      10413.0
# 2                      10780.0                      10825.0
# 3                      10508.0                      10280.0
# 4                       8833.0                       9975.0
#
#    total_reimbursements_b_2013  total_reimbursements_b_2014
# 0                       9489.0                       9412.0
# 1                      10077.0                      10117.0
# 2                      10674.0                      10817.0
# 3                      10092.0                      10035.0
# 4                       9293.0                       9275.0

# %%
#Rename columns

modmedicare_df=medicare_df.rename(columns={
    'geo_name':'Location',
    'geo_id':'Geo ID',
    'total_reimbursements_b_2010':'Reimbursements per Enrollee (2010)',
    'total_reimbursements_b_2011':'Reimbursements per Enrollee (2011)',
    'total_reimbursements_b_2012':'Reimbursements per Enrollee (2012)',
    'total_reimbursements_b_2013':'Reimbursements per Enrollee (2013)',
    'total_reimbursements_b_2014':'Reimbursements per Enrollee (2014)',
})

mod2medicare_df=modmedicare_df.drop(['geo_sumlevel'],axis=1)
mod2medicare_df.head()
# Out:
#              Location        Geo ID  Reimbursements per Enrollee (2010)  \
# 0  Baldwin County, AL  05000US01003                              9618.0
# 1  Barbour County, AL  05000US01005                              9761.0
# 2     Bibb County, AL  05000US01007                             11269.0
# 3   Blount County, AL  05000US01009                             10238.0
# 4  Bullock County, AL  05000US01011                              9567.0
#
#    Reimbursements per Enrollee (2011)  Reimbursements per Enrollee (2012)  \
# 0                              9569.0                              9501.0
# 1                             10718.0                             10413.0
# 2                             10780.0                             10825.0
# 3                             10508.0                             10280.0
# 4                              8833.0                              9975.0
#
#    Reimbursements per Enrollee (2013)  Reimbursements per Enrollee (2014)
# 0                              9489.0                              9412.0
# 1                             10077.0                             10117.0
# 2                             10674.0                             10817.0
# 3                             10092.0                             10035.0
# 4                              9293.0                              9275.0

# %%
#Split "Location" column into separate columns of county and state

mod2medicare_df[['County','State']]=mod2medicare_df['Location'].str.rsplit(',', expand=True)
mod2medicare_df.head()
# Out:
#              Location        Geo ID  Reimbursements per Enrollee (2010)  \
# 0  Baldwin County, AL  05000US01003                              9618.0
# 1  Barbour County, AL  05000US01005                              9761.0
# 2     Bibb County, AL  05000US01007                             11269.0
# 3   Blount County, AL  05000US01009                             10238.0
# 4  Bullock County, AL  05000US01011                              9567.0
#
#    Reimbursements per Enrollee (2011)  Reimbursements per Enrollee (2012)  \
# 0                              9569.0                              9501.0
# 1                             10718.0                             10413.0
# 2                             10780.0                             10825.0
# 3                             10508.0                             10280.0
# 4                              8833.0                              9975.0
#
#    Reimbursements per Enrollee (2013)  Reimbursements per Enrollee (2014)  \
# 0                              9489.0                              9412.0
# 1                             10077.0                             10117.0
# 2                             10674.0                             10817.0
# 3                             10092.0                             10035.0
# 4                              9293.0                              9275.0
#
#            County State
# 0  Baldwin County    AL
# 1  Barbour County    AL
# 2     Bibb County    AL
# 3   Blount County    AL
# 4  Bullock County    AL

# %%
#Reorder columns to shift county and state columns to the left
mod2medicare_df=mod2medicare_df[['County', 'State', 'Geo ID', 'Reimbursements per Enrollee (2010)', 'Reimbursements per Enrollee (2011)','Reimbursements per Enrollee (2012)','Reimbursements per Enrollee (2013)','Reimbursements per Enrollee (2014)']]
mod2medicare_df.head()
# Out:
#            County State        Geo ID  Reimbursements per Enrollee (2010)  \
# 0  Baldwin County    AL  05000US01003                              9618.0
# 1  Barbour County    AL  05000US01005                              9761.0
# 2     Bibb County    AL  05000US01007                             11269.0
# 3   Blount County    AL  05000US01009                             10238.0
# 4  Bullock County    AL  05000US01011                              9567.0
#
#    Reimbursements per Enrollee (2011)  Reimbursements per Enrollee (2012)  \
# 0                              9569.0                              9501.0
# 1                             10718.0                             10413.0
# 2                             10780.0                             10825.0
# 3                             10508.0                             10280.0
# 4                              8833.0                              9975.0
#
#    Reimbursements per Enrollee (2013)  Reimbursements per Enrollee (2014)
# 0                              9489.0                              9412.0
# 1                             10077.0                             10117.0
# 2                             10674.0                             10817.0
# 3                             10092.0                             10035.0
# 4                              9293.0                              9275.0

# %%
mod3medicare_df=mod2medicare_df.set_index('State')
mod3medicare_df.head()
# Out:
#                County        Geo ID  Reimbursements per Enrollee (2010)  \
# State
#  AL    Baldwin County  05000US01003                              9618.0
#  AL    Barbour County  05000US01005                              9761.0
#  AL       Bibb County  05000US01007                             11269.0
#  AL     Blount County  05000US01009                             10238.0
#  AL    Bullock County  05000US01011                              9567.0
#
#        Reimbursements per Enrollee (2011)  Reimbursements per Enrollee (2012)  \
# State
#  AL                                9569.0                              9501.0
#  AL                               10718.0                             10413.0
#  AL                               10780.0                             10825.0
#  AL                               10508.0                             10280.0
#  AL                                8833.0                              9975.0
#
#        Reimbursements per Enrollee (2013)  Reimbursements per Enrollee (2014)
# State
#  AL                                9489.0                              9412.0
#  AL                               10077.0                             10117.0
#  AL                               10674.0                             10817.0
#  AL                               10092.0                             10035.0
#  AL                                9293.0                              9275.0

# %%
ohio_only_df=mod3medicare_df.loc[[' OH']]
ohio_only_df.head()
# Out:
#                  County        Geo ID  Reimbursements per Enrollee (2010)  \
# State
#  OH        Adams County  05000US39001                             10803.0
#  OH        Allen County  05000US39003                              9743.0
#  OH      Ashland County  05000US39005                              8359.0
#  OH    Ashtabula County  05000US39007                             11209.0
#  OH       Athens County  05000US39009                             10423.0
#
#        Reimbursements per Enrollee (2011)  Reimbursements per Enrollee (2012)  \
# State
#  OH                               11583.0                             11199.0
#  OH                               10227.0                             10413.0
#  OH                                8704.0                              8805.0
#  OH                               11538.0                             11291.0
#  OH                               10099.0                              9904.0
#
#        Reimbursements per Enrollee (2013)  Reimbursements per Enrollee (2014)
# State
#  OH                               10875.0                             12341.0
#  OH                               10137.0                             10116.0
#  OH                                8796.0                              8274.0
#  OH                               11131.0                             11231.0
#  OH                               10008.0                             10117.0
